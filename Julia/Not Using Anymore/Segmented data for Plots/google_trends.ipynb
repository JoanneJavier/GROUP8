# %%
from pytrends.request import TrendReq
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
from config import gkey

# %%
#connect to Google
pytrends = TrendReq(hl='en-US', tz=360)

# %%
#build payload
#set parameters
kw_list = ['Tesla']
pytrends.build_payload(kw_list, cat=0, timeframe='2013-09-09 2018-09-01', geo='US-CA',gprop='')

# %%
#pytrends.interest_by_region(resolution = 'CITY')

# %%
tesla_searches = pytrends.interest_over_time()

tesla_searches.head()
# Out:
#             Tesla  isPartial
# date
# 2013-09-15     14      False
# 2013-09-22     14      False
# 2013-09-29     20      False
# 2013-10-06     14      False
# 2013-10-13     13      False

# %%
tesla_df = tesla_searches.drop(columns= "isPartial")

tesla_df.head()
# Out:
#             Tesla
# date
# 2013-09-15     14
# 2013-09-22     14
# 2013-09-29     20
# 2013-10-06     14
# 2013-10-13     13

# %%
plt.figure(figsize=(20,10))
plt.plot(tesla_df)
plt.title("Google Searches for 'Tesla' 2013-2018")
plt.ylabel("% of Searches")
# Out:
# Text(0,0.5,'% of Searches')

# %%
kw_list = ['Prius']
pytrends.build_payload(kw_list, cat=0, timeframe='2013-09-09 2018-09-01', geo='US-CA',gprop='')

# %%
prius_searches = pytrends.interest_over_time()

prius_searches.head()
# Out:
#             Prius  isPartial
# date
# 2013-09-15     51      False
# 2013-09-22     50      False
# 2013-09-29     47      False
# 2013-10-06     53      False
# 2013-10-13     50      False

# %%
prius_df = prius_searches.drop(columns= "isPartial")

prius_df.head()
# Out:
#             Prius
# date
# 2013-09-15     51
# 2013-09-22     50
# 2013-09-29     47
# 2013-10-06     53
# 2013-10-13     50

# %%
plt.figure(figsize=(20,10))
plt.plot(prius_df)
plt.title("Google Searches for 'Prius' 2013-2018")
plt.ylabel("% of Searches")
# Out:
# Text(0,0.5,'% of Searches')
