# %%
import pandas as pd
import csv
import requests
import json
from config import gkey

# %%
#read csv file into a pd data frame
csv_path = "Resources/zipcodes.csv"
zipcodes_original = pd.read_csv(csv_path, header=[0])

#preview data
zipcodes_original.head()
# Out:
#    Zip Code State         County           City  Time Zone  Distance
# 0     94103    CA  San Francisco  San Francisco          8         0
# 1     94119    CA  San Francisco  San Francisco          8         1
# 2     94120    CA  San Francisco  San Francisco          8         1
# 3     94125    CA  San Francisco  San Francisco          8         1
# 4     94126    CA  San Francisco  San Francisco          8         1

# %%
#Drop irrelevant columns
zipcodes_data = zipcodes_original[["Zip Code","County","City"]]

#preview data
zipcodes_data.head()
# Out:
#    Zip Code         County           City
# 0     94103  San Francisco  San Francisco
# 1     94119  San Francisco  San Francisco
# 2     94120  San Francisco  San Francisco
# 3     94125  San Francisco  San Francisco
# 4     94126  San Francisco  San Francisco

# %%
zipcodes_data.nunique()["City"]
# Out:
# 112

# %%
sorted_zipcodes = zipcodes_data.groupby(["City"])
sorted_zipcodes.count()
# Out:
#                      Zip Code  County
# City
# Alameda                     2       2
# Alamo                       1       1
# Albany                      1       1
# Alviso                      1       1
# American Canyon             1       1
# Antioch                     2       2
# Atherton                    1       1
# Belmont                     1       1
# Belvedere Tiburon           1       1
# Benicia                     1       1
# Berkeley                   11      11
# Birds Landing               1       1
# Bolinas                     1       1
# Boyes Hot Springs           1       1
# Brentwood                   1       1
# Brisbane                    1       1
# Burlingame                  2       2
# Canyon                      1       1
# Castro Valley               2       2
# Clayton                     1       1
# Concord                     8       8
# Corte Madera                2       2
# Crockett                    1       1
# ...

# %%
#looked for nearby gas stations
#hard coded location lat and lng. still trying to figure out how to search with zipcode 
location = '37,-122'
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
radius = 2000
params = {"key":gkey,
         "location":"37,-122",
         "radius":radius,
          "type":"gas_station"
         }
query_url = f"{base_url}key={gkey}&location=37,-122&radius={radius}&rankby=prominence&type=gas_station"
query_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyC3SfYMtCuAVDfvt_FycJcXcvEgdgD2tss&location=37,-122&radius=2000&rankby=prominence&type=gas_station'

# %%
response = requests.get(query_url).json()
response
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 36.985107, 'lng': -121.989512},
#     'viewport': {'northeast': {'lat': 36.98646213029149,
#       'lng': -121.9882439697085},
#      'southwest': {'lat': 36.98376416970849, 'lng': -121.9909419302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#    'id': 'b435f935347a87e6c36a85a903625a12a3fa8dfc',
#    'name': 'Shell',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116583062108209279409/photos">Jerry Midland</a>'],
#      'photo_reference': 'CmRaAAAAwaKbqkokWFMR2M-Fgc07gVyBjrok5wiCEj-_IkYL4rbCxmm2ajt-7hiXPwgz87qDG0YMaDUc-AnFdEzj1yfKjdVkXr6e9ESelU6gBTpR9VLb0c5y57tB0UGzjMOUtmdIEhDr5B4FbfAMAC5ID3iNNDjhGhQyOVERDy1IYVr3nqdCcWaHqodyLg',
#      'width': 3024}],
#    'place_id': 'ChIJZ2Ab5f4_joARRbtpihFM5nE',
#    'plus_code': {'compound_code': 'X2P6+25 Live Oak, California, United States',
# ...

# %%
target_cities = ["San Francisco","Sausalito","Novato"]
