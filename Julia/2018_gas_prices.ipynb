# %%
#import dependencies
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#weekly gas prices in San Francisco Area
#read csv 
weekly_gas_prices = pd.read_csv("Resources/2018_weekly_gas_prices_ca.csv")

#rename column 
weekly_gas_prices = weekly_gas_prices.rename(columns={'Weekly San Francisco All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)':'Price'})

#preview data
weekly_gas_prices.head()
# Out:
#         Date  Price
# 0   4-Sep-17  3.221
# 1  11-Sep-17  3.242
# 2  18-Sep-17  3.219
# 3  25-Sep-17  3.199
# 4   2-Oct-17  3.166

# %%
#monthly gas prices in San Francisco Area 
#monthly_gas_prices = pd.read_csv("Resources/monthly_gas_prices.csv")
#monthly_gas_prices = monthly_gas_prices.rename(columns={'San Francisco Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)':'Price'})
#monthly_gas_prices.head()

# %%
ca_weekly = pd.read_csv("Resources/2018_weekly_gas_prices_ca.csv")
ca_weekly = ca_weekly.set_index("Date")
ca_weekly
# Out:
#            Price
# Date
# 4-Sep-17   3.221
# 11-Sep-17  3.242
# 18-Sep-17  3.219
# 25-Sep-17  3.199
# 2-Oct-17   3.166
# 9-Oct-17   3.139
# 16-Oct-17  3.133
# 23-Oct-17  3.120
# 30-Oct-17  3.125
# 6-Nov-17   3.302
# 13-Nov-17  3.335
# 20-Nov-17  3.282
# 27-Nov-17  3.258
# 4-Dec-17   3.218
# 11-Dec-17  3.177
# 18-Dec-17  3.163
# 25-Dec-17  3.191
# 1-Jan-18   3.206
# 8-Jan-18   3.258
# 15-Jan-18  3.256
# 22-Jan-18  3.268
# 29-Jan-18  3.355
# 5-Feb-18   3.428
# 12-Feb-18  3.416
# 19-Feb-18  3.408
# 26-Feb-18  3.418
# 5-Mar-18   3.414
# 12-Mar-18  3.451
# 19-Mar-18  3.492
# 26-Mar-18  3.547
# 2-Apr-18   3.600
# 9-Apr-18   3.580
# 16-Apr-18  3.611
# 23-Apr-18  3.626
# 30-Apr-18  3.667
# 7-May-18   3.690
# 14-May-18  3.672
# 21-May-18  3.689
# 28-May-18  3.708
# 4-Jun-18   3.704
# 11-Jun-18  3.688
# 18-Jun-18  3.664
# 25-Jun-18  3.634
# 2-Jul-18   3.622
# 9-Jul-18   3.626
# 16-Jul-18  3.609
# 23-Jul-18  3.588
# 30-Jul-18  3.579
# 6-Aug-18   3.576
# 13-Aug-18  3.563
# 20-Aug-18  3.538
# 27-Aug-18  3.546
# 3-Sep-18   3.572

# %%
#drop nan values in the df
ca_weekly = ca_weekly.dropna()

# %%
#plot graph for weekly gas price in the whole state of CA 

#data = ca_weekly["Price"]
#weeks = ca_weekly["Date"]
#week_data = weeks.dropna()
#week_list = week_data.tolist()
#tick_locations = [value for value in week_list]
#plt.xticks(tick_locations, week_list)

plt.figure(figsize=(20,10))
plt.plot(ca_weekly)
plt.title("Weekly Gas Prices in California from 2013-2018")
plt.ylabel("Gas Price (Dollars per Gallon)")
plt.xticks(rotation=45)
plt.grid()

plt.show()

#clean up xticks
