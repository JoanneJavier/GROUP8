# %%
import pandas as pd
import csv
import requests
import json
from config import gkey

# %%
#read csv file into a pd data frame
csv_path = "Resources/zipcodes.csv"
zipcodes_original = pd.read_csv(csv_path, header=[0])

#preview data
zipcodes_original.head()
# Out:
#    Zip Code State         County           City  Time Zone  Distance
# 0     94103    CA  San Francisco  San Francisco          8         0
# 1     94119    CA  San Francisco  San Francisco          8         1
# 2     94120    CA  San Francisco  San Francisco          8         1
# 3     94125    CA  San Francisco  San Francisco          8         1
# 4     94126    CA  San Francisco  San Francisco          8         1

# %%
#Drop irrelevant columns
zipcodes_data = zipcodes_original[["Zip Code","County","City"]]

#preview data
zipcodes_data.head()
# Out:
#    Zip Code         County           City
# 0     94103  San Francisco  San Francisco
# 1     94119  San Francisco  San Francisco
# 2     94120  San Francisco  San Francisco
# 3     94125  San Francisco  San Francisco
# 4     94126  San Francisco  San Francisco

# %%
zipcodes_data.nunique()["City"]
zipcodes_by_city = zipcodes_data.groupby(["City"])

# %%
for city in zipcodes_data["City"]:

# %%
#look for nearby gas stations
#hardcoded location lat and lng. still trying to figure out how to search with zipcode 
location = [37,-122]
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
radius = 8000
params = {"key":gkey,
         "location":"37,-122",
         "radius":radius,
          "type":"gas_station"
         }
query_url = f"{base_url}key={gkey}&location=37,-122&radius={radius}&rankby=prominence&keyword=gasstation&type=gas_station"
query_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyBm21S8SElifPdstQts4-UmMz1AzhkG_FA&location=37,-122&radius=8000&rankby=prominence&keyword=gasstation&type=gas_station'

# %%
response = requests.get(query_url).json()
response
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 36.9905657,
#      'lng': -121.9568651},
#     'viewport': {'northeast': {'lat': 36.99199507989272,
#       'lng': -121.9557253201073},
#      'southwest': {'lat': 36.98929542010728, 'lng': -121.9584249798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#    'id': '0ac92d18f2dc178557f12ad9eb09abee143fed3a',
#    'name': 'Quik Stop',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJmZ46aX0VjoARuuQSdMJjpf8',
#    'plus_code': {'compound_code': 'X2RV+67 Soquel, California',
#     'global_code': '848WX2RV+67'},
#    'rating': 2.8,
#    'reference': 'CmRbAAAArtBNHXd1QrmnVDnfgGtBIdMRbH_3B3S18EvXV_PKNer3UgAxhs9pTQ2HTheDyvIDoDv6IDJD8KInuZzpNNJMVDvnuAOcYSH_OjeZ-Hu05Ee57Kor3d1uFSuGdQMAAzTDEhBrx2CXoWr26pjsPyNJghDKGhQ0khGUyHN3nsOcGzuvd63O0QtlVg',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'gas_station',
# ...

# %%
target_cities = ["San Francisco","Sausalito","Novato"]
